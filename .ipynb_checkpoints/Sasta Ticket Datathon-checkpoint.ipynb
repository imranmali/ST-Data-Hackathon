# %% [markdown]
# # Ticket Pridiction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
X_test = pd.read_csv("X_test.csv")

# %%
print(X_test.shape) 
X_test.head()
# Out:
# (4532489, 10)
#                                  f1 f2 f3                         f4  \
# 0  2021-09-01 08:30:19.320999+00:00  x  y  2021-09-08 11:00:00+00:00
# 1  2021-09-01 08:30:19.320999+00:00  x  y  2021-09-08 14:00:00+00:00
# 2  2021-09-01 08:30:19.320999+00:00  x  y  2021-09-08 05:00:00+00:00
# 3  2021-09-01 08:30:20.396761+00:00  x  y  2021-09-08 05:30:00+00:00
# 4  2021-09-01 08:30:20.396761+00:00  x  y  2021-09-08 05:30:00+00:00
#
#                           f5     f6    f7    f8  f9   f10
# 0  2021-09-08 12:55:00+00:00   beta  True  40.0   0  b-69
# 1  2021-09-08 15:55:00+00:00   beta  True  40.0   0   b-9
# 2  2021-09-08 06:55:00+00:00   beta  True  20.0   0   b-1
# 3  2021-09-08 07:30:00+00:00  gamma  True  20.0   2   c-2
# 4  2021-09-08 07:30:00+00:00  gamma  True  20.0   1   c-2

# %%
y_train = pd.read_csv("y_train.csv")

# %%
y_train.head()
# Out:
#    Unnamed: 0   target
# 0           0   7400.0
# 1           1   8650.0
# 2           2   9150.0
# 3           3  10400.0
# 4           4   8697.0

# %%
y_train.columns
# Out:
# Index(['Unnamed: 0', 'target'], dtype='object')

# %%
y_train.drop(['Unnamed: 0'],axis = 1)
# Out:
#            target
# 0          7400.0
# 1          8650.0
# 2          9150.0
# 3         10400.0
# 4          8697.0
# ...           ...
# 21776585   8381.0
# 21776586   9045.0
# 21776587   6155.0
# 21776588   6155.0
# 21776589   6605.0
#
# [21776590 rows x 1 columns]

# %%
X_test.columns
# Out:
# Index(['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10'], dtype='object')

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4532489 entries, 0 to 4532488
# Data columns (total 10 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   f1      object
#  1   f2      object
#  2   f3      object
#  3   f4      object
#  4   f5      object
#  5   f6      object
#  6   f7      bool
#  7   f8      float64
#  8   f9      int64
#  9   f10     object
# dtypes: bool(1), float64(1), int64(1), object(7)
# memory usage: 315.5+ MB

# %%
test_columns = ["Ticket Purchase Date Time","Origin","Destination","Departure Date Time",
                "Arrival Date Time","Airline","Refundable Ticket","Baggage Weight","Baggage Pieces",
                "Flight Number"]

# %%
test_columns
# Out:
# ['Ticket Purchase Date Time',
#  'Origin',
#  'Destination',
#  'Departure Date Time',
#  'Arrival Date Time',
#  'Airline',
#  'Refundable Ticket',
#  'Baggage Weight',
#  'Baggage Pieces',
#  'Flight Number']

# %%
X_test.columns = test_columns

# %%
X_test.columns
# Out:
# Index(['Ticket Purchase Date Time', 'Origin', 'Destination',
#        'Departure Date Time', 'Arrival Date Time', 'Airline',
#        'Refundable Ticket', 'Baggage Weight', 'Baggage Pieces',
#        'Flight Number'],
#       dtype='object')

# %%
X_test.iloc[3:5]
# Out:
#   Origin Destination Airline  Refundable Ticket  Baggage Weight  \
# 3      x           y   gamma               True            20.0
# 4      x           y   gamma               True            20.0
#
#    Baggage Pieces Flight Number  Ticket_Purchase_Day  Ticket_Purchase_Month  \
# 3               2           c-2                    1                      9
# 4               1           c-2                    1                      9
#
#    Ticket_Purchase_Year  Ticket_Purchase_Hour  Ticket_Purchase_Minute  \
# 3                  2021                     8                      30
# 4                  2021                     8                      30
#
#    Departure_Day  Departure_Month  Departure_Year  Departure_Hour  \
# 3              8                9            2021               5
# 4              8                9            2021               5
#
#    Departure_Minute  Arrival_Day  Arrival_Month  Arrival_Year  Arrival_Hour  \
# ...

# %%
X_test.isna().sum()
# Out:
# Ticket Purchase Date Time    0
# Origin                       0
# Destination                  0
# Departure Date Time          0
# Arrival Date Time            0
# Airline                      0
# Refundable Ticket            0
# Baggage Weight               0
# Baggage Pieces               0
# Flight Number                0
# dtype: int64

# %%
dateTimeFormatter = '%Y-%m-%d %H:%M:%S.%f'
X_test[['Ticket Purchase Date Time','Departure Date Time','Arrival Date Time']] = X_test[['Ticket Purchase Date Time','Departure Date Time','Arrival Date Time']].apply(pd.to_datetime, format=dateTimeFormatter)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4532489 entries, 0 to 4532488
# Data columns (total 10 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Ticket Purchase Date Time  datetime64[ns, UTC]
#  1   Origin                     object
#  2   Destination                object
#  3   Departure Date Time        datetime64[ns, UTC]
#  4   Arrival Date Time          datetime64[ns, UTC]
#  5   Airline                    object
#  6   Refundable Ticket          bool
#  7   Baggage Weight             float64
#  8   Baggage Pieces             int64
#  9   Flight Number              object
# dtypes: bool(1), datetime64[ns, UTC](3), float64(1), int64(1), object(4)
# memory usage: 315.5+ MB

# %%
X_test["Ticket_Purchase_Day"] = pd.to_datetime(X_test[test_columns[0]],format=dateTimeFormatter).dt.day
X_test["Ticket_Purchase_Month"] = pd.to_datetime(X_test[test_columns[0]],format=dateTimeFormatter).dt.month
X_test["Ticket_Purchase_Year"] = pd.to_datetime(X_test[test_columns[0]],format=dateTimeFormatter).dt.year
X_test["Ticket_Purchase_Hour"] = pd.to_datetime(X_test[test_columns[0]],format=dateTimeFormatter).dt.hour
X_test["Ticket_Purchase_Minute"] = pd.to_datetime(X_test[test_columns[0]],format=dateTimeFormatter).dt.minute

# %%
X_test["Departure_Day"] = pd.to_datetime(X_test[test_columns[3]],format=dateTimeFormatter).dt.day
X_test["Departure_Month"] = pd.to_datetime(X_test[test_columns[3]],format=dateTimeFormatter).dt.month
X_test["Departure_Year"] = pd.to_datetime(X_test[test_columns[3]],format=dateTimeFormatter).dt.year
X_test["Departure_Hour"] = pd.to_datetime(X_test[test_columns[3]],format=dateTimeFormatter).dt.hour
X_test["Departure_Minute"] = pd.to_datetime(X_test[test_columns[3]],format=dateTimeFormatter).dt.minute

# %%
X_test["Arrival_Day"] = pd.to_datetime(X_test[test_columns[4]],format=dateTimeFormatter).dt.day
X_test["Arrival_Month"] = pd.to_datetime(X_test[test_columns[4]],format=dateTimeFormatter).dt.month
X_test["Arrival_Year"] = pd.to_datetime(X_test[test_columns[4]],format=dateTimeFormatter).dt.year
X_test["Arrival_Hour"] = pd.to_datetime(X_test[test_columns[4]],format=dateTimeFormatter).dt.hour
X_test["Arrival_Minute"] = pd.to_datetime(X_test[test_columns[4]],format=dateTimeFormatter).dt.minute

# %%
X_test.tail()
# Out:
#                Ticket Purchase Date Time Origin Destination  \
# 4532484 2021-09-30 00:12:02.332762+00:00      x           y
# 4532485 2021-09-30 00:12:02.332762+00:00      x           y
# 4532486 2021-09-30 00:12:03.210520+00:00      x           y
# 4532487 2021-09-30 00:12:03.210520+00:00      x           y
# 4532488 2021-09-30 00:12:03.210520+00:00      x           y
#
#               Departure Date Time         Arrival Date Time Airline  \
# 4532484 2021-09-30 16:00:00+00:00 2021-09-30 18:00:00+00:00   alpha
# 4532485 2021-09-30 16:00:00+00:00 2021-09-30 18:00:00+00:00   alpha
# 4532486 2021-09-30 17:05:00+00:00 2021-09-30 19:05:00+00:00   omega
# 4532487 2021-09-30 10:50:00+00:00 2021-09-30 12:50:00+00:00   omega
# 4532488 2021-09-30 04:45:00+00:00 2021-09-30 06:45:00+00:00   omega
#
#          Refundable Ticket  Baggage Weight  Baggage Pieces Flight Number  \
# 4532484               True            15.0               1          a-23
# ...

# %%
X_test.drop([test_columns[0],test_columns[3], test_columns[4]], axis = 1, inplace = True)

# %%
X_test.head()
# Out:
#   Origin Destination Airline  Refundable Ticket  Baggage Weight  \
# 0      x           y    beta               True            40.0
# 1      x           y    beta               True            40.0
# 2      x           y    beta               True            20.0
# 3      x           y   gamma               True            20.0
# 4      x           y   gamma               True            20.0
#
#    Baggage Pieces Flight Number  Ticket_Purchase_Day  Ticket_Purchase_Month  \
# 0               0          b-69                    1                      9
# 1               0           b-9                    1                      9
# 2               0           b-1                    1                      9
# 3               2           c-2                    1                      9
# 4               1           c-2                    1                      9
#
#    Ticket_Purchase_Year  Ticket_Purchase_Hour  Ticket_Purchase_Minute  \
# ...

# %%
X_test['Baggage Weight'].unique()
# Out:
# array([40., 20., 15.,  0.])

# %%
X_test['Flight Number'].unique()
# Out:
# array(['b-69', 'b-9', 'b-1', 'c-2', 'c-4', 'c-6', 'a-1', 'a-5', 'a-7',
#        'a-9', 'a-23', 'd-1', 'd-5', 'd-3', 'b-73', 'b-19', 'b-319',
#        'b-67', 'b-369'], dtype=object)

# %%
print(X_test.shape[0])
print(y_train.shape[0])
y_train.shape[0] - X_test.shape[0]
# Out:
# 4532489
# 21776590
# 17244101

# %%
X_test['Airline'].unique()
# Out:
# array(['beta', 'gamma', 'alpha', 'omega'], dtype=object)

# %%
X_test['Refundable Ticket'].unique()
# Out:
# array([ True])

# %%
X_test = X_test.drop(['Origin','Destination','Refundable Ticket'],axis = 1)

# %%
X_test.head()
# Out:
#   Airline  Baggage Weight  Baggage Pieces Flight Number  Ticket_Purchase_Day  \
# 0    beta            40.0               0          b-69                    1
# 1    beta            40.0               0           b-9                    1
# 2    beta            20.0               0           b-1                    1
# 3   gamma            20.0               2           c-2                    1
# 4   gamma            20.0               1           c-2                    1
#
#    Ticket_Purchase_Month  Ticket_Purchase_Year  Ticket_Purchase_Hour  \
# 0                      9                  2021                     8
# 1                      9                  2021                     8
# 2                      9                  2021                     8
# 3                      9                  2021                     8
# 4                      9                  2021                     8
#
#    Ticket_Purchase_Minute  Departure_Day  Departure_Month  Departure_Year  \
# ...

# %%
X_train = pd.read_csv("X_train.csv")

# %%
X_train.head(10)
# Out:
#    Unnamed: 0                                f1 f2 f3  \
# 0           0  2020-12-31 09:46:17.463002+00:00  x  y
# 1           1  2020-12-31 09:46:17.463002+00:00  x  y
# 2           2  2020-12-31 09:46:17.463002+00:00  x  y
# 3           3  2020-12-31 09:46:17.463002+00:00  x  y
# 4           4  2020-12-31 09:46:18.191119+00:00  x  y
# 5           5  2020-12-31 09:46:18.191119+00:00  x  y
# 6           6  2020-12-31 09:46:18.191119+00:00  x  y
# 7           7  2020-12-31 09:46:18.191119+00:00  x  y
# 8           8  2020-12-31 09:46:19.878719+00:00  x  y
# 9           9  2020-12-31 09:46:19.878719+00:00  x  y
#
#                           f4                         f5     f6     f7    f8  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True   0.0
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True  32.0
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   True  32.0
# ...

# %%
X_train.shape
# Out:
# (21776590, 11)

# %%
(y_train.shape)
# Out:
# (21776590, 2)

# %%
test_columns
# Out:
# ['Ticket Purchase Date Time',
#  'Origin',
#  'Destination',
#  'Departure Date Time',
#  'Arrival Date Time',
#  'Airline',
#  'Refundable Ticket',
#  'Baggage Weight',
#  'Baggage Pieces',
#  'Flight Number']

# %%
def prepareDate(df):
    df = df.drop(['Unnamed: 0'],axis = 1)
    df.columns = test_columns
    df[[test_columns[0],test_columns[3],test_columns[4]]] = df[[test_columns[0],test_columns[3],test_columns[4]]].apply(pd.to_datetime, format=dateTimeFormatter)
    #formatting date time
    df["Ticket_Purchase_Day"] = pd.to_datetime(df[test_columns[0]],format=dateTimeFormatter).dt.day
    df["Ticket_Purchase_Month"] = pd.to_datetime(df[test_columns[0]],format=dateTimeFormatter).dt.month
    df["Ticket_Purchase_Year"] = pd.to_datetime(df[test_columns[0]],format=dateTimeFormatter).dt.year
    df["Ticket_Purchase_Hour"] = pd.to_datetime(df[test_columns[0]],format=dateTimeFormatter).dt.hour
    df["Ticket_Purchase_Minute"] = pd.to_datetime(df[test_columns[0]],format=dateTimeFormatter).dt.minute

    df["Departure_Day"] = pd.to_datetime(df[test_columns[3]],format=dateTimeFormatter).dt.day
    df["Departure_Month"] = pd.to_datetime(df[test_columns[3]],format=dateTimeFormatter).dt.month
    df["Departure_Year"] = pd.to_datetime(df[test_columns[3]],format=dateTimeFormatter).dt.year
    df["Departure_Hour"] = pd.to_datetime(df[test_columns[3]],format=dateTimeFormatter).dt.hour
    df["Departure_Minute"] = pd.to_datetime(df[test_columns[3]],format=dateTimeFormatter).dt.minute
    
    df["Arrival_Day"] = pd.to_datetime(df[test_columns[4]],format=dateTimeFormatter).dt.day
    df["Arrival_Month"] = pd.to_datetime(df[test_columns[4]],format=dateTimeFormatter).dt.month
    df["Arrival_Year"] = pd.to_datetime(df[test_columns[4]],format=dateTimeFormatter).dt.year
    df["Arrival_Hour"] = pd.to_datetime(df[test_columns[4]],format=dateTimeFormatter).dt.hour
    df["Arrival_Minute"] = pd.to_datetime(df[test_columns[4]],format=dateTimeFormatter).dt.minute

    #df = df.drop([test_columns[0],test_columns[1],test_columns[2],test_columns[3], test_columns[4]], axis = 1, inplace = True)
    return df

# %%
X_train_1 = prepareDate(X_train)

# %%
X_train_1.head()
# Out:
#          Ticket Purchase Date Time Origin Destination  \
# 0 2020-12-31 09:46:17.463002+00:00      x           y
# 1 2020-12-31 09:46:17.463002+00:00      x           y
# 2 2020-12-31 09:46:17.463002+00:00      x           y
# 3 2020-12-31 09:46:17.463002+00:00      x           y
# 4 2020-12-31 09:46:18.191119+00:00      x           y
#
#         Departure Date Time         Arrival Date Time Airline  \
# 0 2021-01-10 05:00:00+00:00 2021-01-10 07:00:00+00:00   gamma
# 1 2021-01-10 05:00:00+00:00 2021-01-10 07:00:00+00:00   gamma
# 2 2021-01-10 11:00:00+00:00 2021-01-10 13:00:00+00:00   gamma
# 3 2021-01-10 11:00:00+00:00 2021-01-10 13:00:00+00:00   gamma
# 4 2021-01-25 11:00:00+00:00 2021-01-25 12:55:00+00:00    beta
#
#    Refundable Ticket  Baggage Weight  Baggage Pieces Flight Number  \
# 0               True             0.0               0           c-2
# 1               True            32.0               1           c-2
# ...

# %%
def prepareDate1(df):
    return df

# %%
xxx = prepareDate1(X_train)
xxx.head()
# Out:
#    Unnamed: 0                                f1 f2 f3  \
# 0           0  2020-12-31 09:46:17.463002+00:00  x  y
# 1           1  2020-12-31 09:46:17.463002+00:00  x  y
# 2           2  2020-12-31 09:46:17.463002+00:00  x  y
# 3           3  2020-12-31 09:46:17.463002+00:00  x  y
# 4           4  2020-12-31 09:46:18.191119+00:00  x  y
#
#                           f4                         f5     f6     f7    f8  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True   0.0
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True  32.0
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   True  32.0
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   True  32.0
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   beta  False  20.0
#
#    f9   f10
# 0   0   c-2
# 1   1   c-2
# 2   1   c-4
# 3   2   c-4
# 4   0  b-69
